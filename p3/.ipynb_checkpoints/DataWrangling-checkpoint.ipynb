# %% [markdown]
# # CSV

# %%
import os
import pandas as pd
import numpy as np

DATADIR = ""
DATAFILE = "beatles-diskography.csv"


def parse_file(datafile):
    df = pd.read_csv(datafile)
    return df.replace(np.nan,'', regex=True).T.to_dict()


def test():
    # a simple test of your implemetation
    datafile = os.path.join(DATADIR, DATAFILE)
    d = parse_file(datafile)
    firstline = {'Title': 'Please Please Me', 'UK Chart Position': '1', 'Label': 'Parlophone(UK)', 'Released': '22 March 1963', 'US Chart Position': '-', 'RIAA Certification': 'Platinum', 'BPI Certification': 'Gold'}
    tenthline = {'Title': '', 'UK Chart Position': '1', 'Label': 'Parlophone(UK)', 'Released': '10 July 1964', 'US Chart Position': '-', 'RIAA Certification': '', 'BPI Certification': 'Gold'}

    assert d[0] == firstline
    assert d[9] == tenthline

    
test()

# %%
"""
Your task is to process the supplied file and use the csv module to extract data from it.
The data comes from NREL (National Renewable Energy Laboratory) website. Each file
contains information from one meteorological station, in particular - about amount of
solar and wind energy for each hour of day.

Note that the first line of the datafile is neither data entry, nor header. It is a line
describing the data source. You should extract the name of the station from it.

The data should be returned as a list of lists (not dictionaries).
You can use the csv modules "reader" method to get data in such format.
Another useful method is next() - to get the next line from the iterator.
You should only change the parse_file function.
"""
import csv
import os

DATADIR = ""
DATAFILE = "745090.csv"


def parse_file(datafile):
    name = ""
    data = []
    with open(datafile,'rb') as f:
        csv_reader = csv.reader(f)
        station_data = csv_reader.next()
        header = csv_reader.next()
        name = station_data[1]
        for row in csv_reader:
            data.append(row)
    
    # Do not change the line below
    return (name, data)


def test():
    datafile = os.path.join(DATADIR, DATAFILE)
    name, data = parse_file(datafile)
    
    assert name == "MOUNTAIN VIEW MOFFETT FLD NAS"
    assert data[0][1] == "01:00"
    assert data[2][0] == "01/01/2005"
    assert data[2][5] == "2"

test()

# %% [markdown]
# # Excel

# %%
import xlrd
from zipfile import ZipFile
datafile = "2013_ERCOT_Hourly_Load_Data.xls"


def open_zip(datafile):
    with ZipFile('{0}.zip'.format(datafile), 'r') as myzip:
        myzip.extractall()
       

def parse_file(datafile):
    workbook = xlrd.open_workbook(datafile)
    sheet = workbook.sheet_by_index(0)
    
    cols = sheet.col_values(1)
    cols.pop(0)
    
    max_val = max(cols)
    min_val = min(cols)
    
    max_time = xlrd.xldate_as_tuple(sheet.cell_value(cols.index(max_val)+1,0),0)
    min_time = xlrd.xldate_as_tuple(sheet.cell_value(cols.index(min_val)+1,0),0)
    data = {
            'maxtime': max_time,
            'maxvalue': max_val,
            'mintime': min_time,
            'minvalue': min_val,
            'avgcoast': sum(cols)/len(cols)
    }
    return data


def test():
    open_zip(datafile)
    data = parse_file(datafile)
    print data

    
    assert round(data['maxvalue'], 10) == round(18779.02551, 10)
    assert data['maxtime'] == (2013, 8, 13, 17, 0, 0)


test()
# Out:
# {'mintime': (2013, 2, 3, 4, 0, 0), 'maxtime': (2013, 8, 13, 17, 0, 0), 'avgcoast': 10976.933460679751, 'maxvalue': 18779.025510000003, 'minvalue': 6602.113898999982}

# %% [markdown]
# # Excel to CSV

# %%
'''
Find the time and value of max load for each of the regions
COAST, EAST, FAR_WEST, NORTH, NORTH_C, SOUTHERN, SOUTH_C, WEST
and write the result out in a csv file, using pipe character | as the delimiter.

An example output can be seen in the "example.csv" file.
'''

import xlrd
import os
import csv
from zipfile import ZipFile

datafile = "2013_ERCOT_Hourly_Load_Data.xls"
outfile = "2013_Max_Loads.csv"


def open_zip(datafile):
    with ZipFile('{0}.zip'.format(datafile), 'r') as myzip:
        myzip.extractall()


def parse_file(datafile):
    workbook = xlrd.open_workbook(datafile)
    sheet = workbook.sheet_by_index(0)
    data = []
    for col in range(1,sheet.ncols):
        station = sheet.cell_value(0,col)
        if station == 'ERCOT':
            continue
        cols = sheet.col_values(col)
        cols.pop(0)
        max_val = max(cols)
    
        year, month, day, hour, minute, second = xlrd.xldate_as_tuple(sheet.cell_value(cols.index(max_val)+1,0),0)
        row = {
            'Station': station,
            'Year': year,
            'Month': month,
            'Day': day,
            'Hour': hour,
            'Max Load':max_val
        }
        data.append(row)
    
    return data

def save_file(data, filename):
    with open(filename, 'wb') as csvfile:
        fieldnames = ['Station','Year','Month','Day','Hour','Max Load']
        w = csv.DictWriter(csvfile, fieldnames=fieldnames, delimiter='|')
        w.writeheader()
        w.writerows(data)
    
def test():
    open_zip(datafile)
    data = parse_file(datafile)
    save_file(data, outfile)

    number_of_rows = 0
    stations = []

    ans = {'FAR_WEST': {'Max Load': '2281.2722140000024',
                        'Year': '2013',
                        'Month': '6',
                        'Day': '26',
                        'Hour': '17'}}
    correct_stations = ['COAST', 'EAST', 'FAR_WEST', 'NORTH',
                        'NORTH_C', 'SOUTHERN', 'SOUTH_C', 'WEST']
    fields = ['Year', 'Month', 'Day', 'Hour', 'Max Load']

    with open(outfile) as of:
        csvfile = csv.DictReader(of, delimiter="|")
        for line in csvfile:
            station = line['Station']
            if station == 'FAR_WEST':
                for field in fields:
                    # Check if 'Max Load' is within .1 of answer
                    if field == 'Max Load':
                        max_answer = round(float(ans[station][field]), 1)
                        max_line = round(float(line[field]), 1)
                        assert max_answer == max_line

                    # Otherwise check for equality
                    else:
                        assert ans[station][field] == line[field]

            number_of_rows += 1
            stations.append(station)

        # Output should be 8 lines not including header
        assert number_of_rows == 8

        # Check Station Names
        assert set(stations) == set(correct_stations)

test()

# %% [markdown]
# # JSON

# %%
import json
import requests


BASE_URL = "http://musicbrainz.org/ws/2/"
ARTIST_URL = BASE_URL + "artist/"

query_type = {  "simple": {},
                "atr": {"inc": "aliases+tags+ratings"},
                "aliases": {"inc": "aliases"},
                "releases": {"inc": "releases"}}


def query_site(url, params, uid="", fmt="json"):
    params["fmt"] = fmt
    r = requests.get(url + uid, params=params)
    print "requesting", r.url

    if r.status_code == requests.codes.ok:
        return r.json()
    else:
        r.raise_for_status()


def query_by_name(url, params, name):
    params["query"] = "artist:" + name
    return query_site(url, params)


def pretty_print(data, indent=4):
    if type(data) == dict:
        print json.dumps(data, indent=indent, sort_keys=True)
    else:
        print data

def main():
    results = query_by_name(ARTIST_URL, query_type["simple"], "Queen")
    pretty_print(results)

    artist_id = results["artists"][1]["id"]
    print "\nARTIST:"
    pretty_print(results["artists"][1])

    artist_data = query_site(ARTIST_URL, query_type["releases"], artist_id)
    releases = artist_data["releases"]
    print "\nONE RELEASE:"
    pretty_print(releases[0], indent=2)
    release_titles = [r["title"] for r in releases]

    print "\nALL TITLES:"
    for t in release_titles:
        print t


main()
# Out:
# requesting http://musicbrainz.org/ws/2/artist/?query=artist%3AQueen&fmt=json
# {
#     "artists": [
#         {
#             "aliases": [
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Queen",
#                     "primary": null,
#                     "sort-name": "Queen",
#                     "type": null
#                 }
#             ],
#             "area": {
#                 "id": "2db42837-c832-3c27-b4a3-08198f75693c",
#                 "name": "Japan",
#                 "sort-name": "Japan"
#             },
#             "country": "JP",
#             "disambiguation": "character, voiced by \u677f\u91ce\u53cb\u7f8e / Itano Tomomi",
#             "gender": "female",
#             "id": "420ca290-76c5-41af-999e-564d7c71f1a7",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Queen",
#             "score": "100",
#             "sort-name": "Queen",
#             "tags": [
#                 {
#                     "count": 1,
#                     "name": "related-akb48"
#                 },
#                 {
#                     "count": 1,
#                     "name": "kamen rider w"
#                 }
#             ],
#             "type": "Character"
#         },
#         {
#             "disambiguation": "US rapper",
#             "id": "5eecaf18-02ec-47af-a4f2-7831db373419",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Queen",
#             "score": "100",
#             "sort-name": "Queen"
#         },
#         {
#             "aliases": [
#                 {
#                     "begin-date": "2011",
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Queen + Adam Lambert",
#                     "primary": null,
#                     "sort-name": "Queen + Adam Lambert",
#                     "type": null
#                 }
#             ],
#             "area": {
#                 "id": "8a754a16-0027-3a29-b6d7-2b40ea0481ed",
#                 "name": "United Kingdom",
#                 "sort-name": "United Kingdom"
#             },
#             "begin-area": {
#                 "id": "f03d09b3-39dc-4083-afd6-159e3f0d462f",
#                 "name": "London",
#                 "sort-name": "London"
#             },
#             "country": "GB",
#             "disambiguation": "UK rock group",
#             "id": "0383dadf-2a4e-4d10-a46a-e9e041da8eb3",
#             "life-span": {
#                 "begin": "1970-06-27",
#                 "ended": null
#             },
#             "name": "Queen",
#             "score": "100",
#             "sort-name": "Queen",
#             "tags": [
#                 {
#                     "count": 9,
#                     "name": "rock"
#                 },
#                 {
#                     "count": 0,
#                     "name": "progressive rock"
#                 },
#                 {
#                     "count": -2,
#                     "name": "70s"
#                 },
#                 {
#                     "count": -2,
#                     "name": "80s"
#                 },
#                 {
#                     "count": -2,
#                     "name": "90s"
#                 },
#                 {
#                     "count": -1,
#                     "name": "pop-rock"
#                 },
#                 {
#                     "count": 3,
#                     "name": "british"
#                 },
#                 {
#                     "count": 0,
#                     "name": "uk"
#                 },
#                 {
#                     "count": 0,
#                     "name": "band"
#                 },
#                 {
#                     "count": 3,
#                     "name": "hard rock"
#                 },
#                 {
#                     "count": 0,
#                     "name": "britannique"
#                 },
#                 {
#                     "count": 0,
#                     "name": "disco"
#                 },
#                 {
#                     "count": 1,
#                     "name": "glam rock"
#                 },
#                 {
#                     "count": -1,
#                     "name": "queen family"
#                 },
#                 {
#                     "count": 2,
#                     "name": "art rock"
#                 },
#                 {
#                     "count": 1,
#                     "name": "pop rock"
#                 },
#                 {
#                     "count": 0,
#                     "name": "english"
#                 },
#                 {
#                     "count": 0,
#                     "name": "united kingdom"
#                 },
#                 {
#                     "count": -1,
#                     "name": "queen"
#                 },
#                 {
#                     "count": -1,
#                     "name": "classic pop and rock"
#                 },
#                 {
#                     "count": -1,
#                     "name": "platinum"
#                 },
#                 {
#                     "count": -1,
#                     "name": "pop/rock"
#                 },
#                 {
#                     "count": 0,
#                     "name": "80's"
#                 },
#                 {
#                     "count": -1,
#                     "name": "90's"
#                 },
#                 {
#                     "count": 0,
#                     "name": "70's"
#                 },
#                 {
#                     "count": 0,
#                     "name": "langham 1 studio bbc"
#                 },
#                 {
#                     "count": 0,
#                     "name": "kind of magic"
#                 }
#             ],
#             "type": "Group"
#         },
#         {
#             "aliases": [
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Acic Queen",
#                     "primary": null,
#                     "sort-name": "Acic Queen",
#                     "type": null
#                 }
#             ],
#             "id": "8a03436b-2120-4d04-9f3b-9e18753ba8b7",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Acid Queen",
#             "score": "62",
#             "sort-name": "Acid Queen",
#             "type": "Group"
#         },
#         {
#             "gender": "female",
#             "id": "c6303af1-d66e-4e8a-930e-fe1d6ea5b781",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Queen Majeeda",
#             "score": "62",
#             "sort-name": "Queen Majeeda",
#             "type": "Person"
#         },
#         {
#             "id": "8d25fda6-e74e-45ac-9695-7e3e6a7d0fac",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "B.B. Queen",
#             "score": "62",
#             "sort-name": "B.B. Queen"
#         },
#         {
#             "area": {
#                 "id": "08310658-51eb-3801-80de-5a0739207115",
#                 "name": "France",
#                 "sort-name": "France"
#             },
#             "country": "FR",
#             "id": "ea57c459-a6dd-40ea-b489-03b7a912be13",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Sister Queen",
#             "score": "62",
#             "sort-name": "Sister Queen",
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "8a754a16-0027-3a29-b6d7-2b40ea0481ed",
#                 "name": "United Kingdom",
#                 "sort-name": "United Kingdom"
#             },
#             "country": "GB",
#             "gender": "female",
#             "id": "9a86679d-7661-4633-b1b0-76a69922458c",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Monica Queen",
#             "score": "62",
#             "sort-name": "Queen, Monica",
#             "tags": [
#                 {
#                     "count": 1,
#                     "name": "country"
#                 }
#             ],
#             "type": "Person"
#         },
#         {
#             "id": "f45984aa-f1ca-41d8-898a-af07340ae244",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Pearly Queen",
#             "score": "62",
#             "sort-name": "Pearly Queen",
#             "tags": [
#                 {
#                     "count": 1,
#                     "name": "funk"
#                 },
#                 {
#                     "count": 1,
#                     "name": "rhythm and blues"
#                 },
#                 {
#                     "count": 1,
#                     "name": "latin"
#                 },
#                 {
#                     "count": 1,
#                     "name": "latin funk"
#                 }
#             ],
#             "type": "Group"
#         },
#         {
#             "id": "b9de990e-2ece-42dd-827c-30c4ca4a99a4",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Queen V",
#             "score": "62",
#             "sort-name": "Queen V"
#         },
#         {
#             "aliases": [
#                 {
#                     "begin-date": null,
#                     "end-date": null,
#                     "locale": null,
#                     "name": "Queen Elisabeth",
#                     "primary": null,
#                     "sort-name": "Queen Elisabeth",
#                     "type": null
#                 }
#             ],
#             "area": {
#                 "id": "8a754a16-0027-3a29-b6d7-2b40ea0481ed",
#                 "name": "United Kingdom",
#                 "sort-name": "United Kingdom"
#             },
#             "country": "GB",
#             "disambiguation": "British band with Julian Cope",
#             "id": "1e067199-f4cd-477b-9a87-7170e7ed4cf7",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Queen Elizabeth",
#             "score": "62",
#             "sort-name": "Queen Elizabeth",
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "08310658-51eb-3801-80de-5a0739207115",
#                 "name": "France",
#                 "sort-name": "France"
#             },
#             "country": "FR",
#             "id": "ee2d368e-3580-46d3-9de7-84110254b6c0",
#             "life-span": {
#                 "begin": "1977",
#                 "ended": null
#             },
#             "name": "Queen Samantha",
#             "score": "62",
#             "sort-name": "Queen Samantha",
#             "type": "Group"
#         },
#         {
#             "id": "eceb4f3d-95d9-4566-9fe2-a307fbcc3a4b",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Black Queen",
#             "score": "62",
#             "sort-name": "Black Queen"
#         },
#         {
#             "area": {
#                 "id": "85752fda-13c4-31a3-bee5-0e5cb1f51dad",
#                 "name": "Germany",
#                 "sort-name": "Germany"
#             },
#             "country": "DE",
#             "disambiguation": "German duo Ina M\u00fcller & Edda Schnittgard",
#             "id": "fd31549e-6a5f-4ff8-94fa-5a68638952fc",
#             "life-span": {
#                 "begin": "1994",
#                 "end": "2005",
#                 "ended": true
#             },
#             "name": "Queen Bee",
#             "score": "62",
#             "sort-name": "Queen Bee",
#             "type": "Group"
#         },
#         {
#             "area": {
#                 "id": "3906cf32-00a7-32df-93cc-4710c5f5a542",
#                 "name": "Puerto Rico",
#                 "sort-name": "Puerto Rico"
#             },
#             "country": "PR",
#             "gender": "female",
#             "id": "ff06ecc0-72a5-4a81-a253-d840d9aefb32",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Ivy Queen",
#             "score": "62",
#             "sort-name": "Ivy Queen",
#             "tags": [
#                 {
#                     "count": 1,
#                     "name": "reggaet\u00f3n"
#                 }
#             ],
#             "type": "Person"
#         },
#         {
#             "area": {
#                 "id": "489ce91b-6658-3307-9877-795b68554c98",
#                 "name": "United States",
#                 "sort-name": "United States"
#             },
#             "begin-area": {
#                 "id": "a71b0d32-7752-49e9-8594-2247ad6ac12c",
#                 "name": "Brooklyn",
#                 "sort-name": "Brooklyn"
#             },
#             "country": "US",
#             "gender": "female",
#             "id": "e6476e4f-ad4c-4e29-bd20-0cd622ffe441",
#             "life-span": {
#                 "begin": "1973",
#                 "ended": null
#             },
#             "name": "Queen Pen",
#             "score": "62",
#             "sort-name": "Pen, Queen",
#             "type": "Person"
#         },
#         {
#             "id": "fbd2bc49-d2dd-410d-a870-950e56f02d5b",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Filter Queen",
#             "score": "62",
#             "sort-name": "Filter Queen"
#         },
#         {
#             "id": "26069161-b64d-4021-9c7e-7686dae8ffb4",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Pork Queen",
#             "score": "62",
#             "sort-name": "Pork Queen"
#         },
#         {
#             "id": "8eb2fc14-e41d-4c02-b3f2-4a4fa3d88664",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Witch Queen",
#             "score": "62",
#             "sort-name": "Witch Queen"
#         },
#         {
#             "id": "8636f35d-0e6c-447e-a77f-718a85124b80",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Stampede Queen",
#             "score": "62",
#             "sort-name": "Stampede Queen",
#             "type": "Group"
#         },
#         {
#             "id": "b46cb0af-039b-4966-9c3e-43a29823778e",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Jenny Queen",
#             "score": "62",
#             "sort-name": "Queen, Jenny",
#             "type": "Person"
#         },
#         {
#             "id": "e74250aa-8f69-426c-9a10-944e53ac5dba",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Queen Mecca",
#             "score": "62",
#             "sort-name": "Queen Mecca"
#         },
#         {
#             "id": "a4bb4530-95a8-4877-b4d7-44ada42846dc",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Disco Queen",
#             "score": "62",
#             "sort-name": "Disco Queen"
#         },
#         {
#             "id": "8636578b-9eeb-4bc5-844f-6816890d230c",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Queen Omega",
#             "score": "62",
#             "sort-name": "Queen Omega"
#         },
#         {
#             "gender": "male",
#             "id": "ff1f59d7-4675-4029-9833-816b1d1bcf9d",
#             "life-span": {
#                 "ended": null
#             },
#             "name": "Size Queen",
#             "score": "62",
#             "sort-name": "Size Queen",
#             "type": "Person"
#         }
#     ],
#     "count": 268,
#     "created": "2017-01-27T14:17:14.439Z",
#     "offset": 0
# }
#
# ARTIST:
# {
#     "disambiguation": "US rapper",
#     "id": "5eecaf18-02ec-47af-a4f2-7831db373419",
#     "life-span": {
#         "ended": null
#     },
#     "name": "Queen",
#     "score": "100",
#     "sort-name": "Queen"
# }
# requesting http://musicbrainz.org/ws/2/artist/5eecaf18-02ec-47af-a4f2-7831db373419?fmt=json&inc=releases
#
# ONE RELEASE:
# {
#   "barcode": "",
#   "country": "US",
#   "date": "2015-04-21",
#   "disambiguation": "",
#   "id": "e53a4efc-bbe2-4422-958f-720920dce51b",
#   "packaging": "None",
#   "packaging-id": "119eba76-b343-3e02-a292-f0f00644bb9b",
#   "quality": "normal",
#   "release-events": [
#     {
#       "area": {
#         "disambiguation": "",
#         "id": "489ce91b-6658-3307-9877-795b68554c98",
#         "iso-3166-1-codes": [
#           "US"
#         ],
#         "name": "United States",
#         "sort-name": "United States"
#       },
#       "date": "2015-04-21"
#     }
#   ],
#   "status": "Official",
#   "status-id": "4e304316-386d-3409-af2e-78857eec5cfe",
#   "text-representation": {
#     "language": "eng",
#     "script": "Latn"
#   },
#   "title": "But I Still Love You"
# }
#
# ALL TITLES:
# But I Still Love You
# Unadorned

# %% [markdown]
# # Wrangling JSON

# %%
"""
This exercise shows some important concepts that you should be aware about:
- using codecs module to write unicode files
- using authentication with web APIs
- using offset when accessing web APIs

To run this code locally you have to register at the NYTimes developer site 
and get your own API key. You will be able to complete this exercise in our UI
without doing so, as we have provided a sample result. (See the file 
'popular-viewed-1.json' from the tabs above.)

Your task is to modify the article_overview() function to process the saved
file that represents the most popular articles (by view count) from the last
day, and return a tuple of variables containing the following data:
- labels: list of dictionaries, where the keys are the "section" values and
  values are the "title" values for each of the retrieved articles.
- urls: list of URLs for all 'media' entries with "format": "Standard Thumbnail"

All your changes should be in the article_overview() function. See the test() 
function for examples of the elements of the output lists.
The rest of functions are provided for your convenience, if you want to access
the API by yourself.
"""
import json
import codecs
import requests

URL_MAIN = "http://api.nytimes.com/svc/"
URL_POPULAR = URL_MAIN + "mostpopular/v2/"
API_KEY = { "popular": "",
            "article": ""}


def get_from_file(kind, period):
    filename = "popular-{0}-{1}.json".format(kind, period)
    with open(filename, "r") as f:
        return json.loads(f.read())


def article_overview(kind, period):
    data = get_from_file(kind, period)
    print data
    titles = []
    urls =[]
    # YOUR CODE HERE

    return (titles, urls)


def query_site(url, target, offset):
    # This will set up the query with the API key and offset
    # Web services often use offset paramter to return data in small chunks
    # NYTimes returns 20 articles per request, if you want the next 20
    # You have to provide the offset parameter
    if API_KEY["popular"] == "" or API_KEY["article"] == "":
        print "You need to register for NYTimes Developer account to run this program."
        print "See Intructor notes for information"
        return False
    params = {"api-key": API_KEY[target], "offset": offset}
    r = requests.get(url, params = params)

    if r.status_code == requests.codes.ok:
        return r.json()
    else:
        r.raise_for_status()


def get_popular(url, kind, days, section="all-sections", offset=0):
    # This function will construct the query according to the requirements of the site
    # and return the data, or print an error message if called incorrectly
    if days not in [1,7,30]:
        print "Time period can be 1,7, 30 days only"
        return False
    if kind not in ["viewed", "shared", "emailed"]:
        print "kind can be only one of viewed/shared/emailed"
        return False

    url += "most{0}/{1}/{2}.json".format(kind, section, days)
    data = query_site(url, "popular", offset)

    return data


def save_file(kind, period):
    # This will process all results, by calling the API repeatedly with supplied offset value,
    # combine the data and then write all results in a file.
    data = get_popular(URL_POPULAR, "viewed", 1)
    num_results = data["num_results"]
    full_data = []
    with codecs.open("popular-{0}-{1}.json".format(kind, period), encoding='utf-8', mode='w') as v:
        for offset in range(0, num_results, 20):        
            data = get_popular(URL_POPULAR, kind, period, offset=offset)
            full_data += data["results"]
        
        v.write(json.dumps(full_data, indent=2))


def test():
    titles, urls = article_overview("viewed", 1)
    assert len(titles) == 20
    assert len(urls) == 30
    assert titles[2] == {'Opinion': 'Professors, We Need You!'}
    assert urls[20] == 'http://graphics8.nytimes.com/images/2014/02/17/sports/ICEDANCE/ICEDANCE-thumbStandard.jpg'


test()
# Out:
# [{u'asset_id': 100000002711650.0, u'byline': u'By ELI J. FINKEL', u'title': u'The All-or-Nothing Marriage', u'url': u'http://www.nytimes.com/2014/02/15/opinion/sunday/the-all-or-nothing-marriage.html', u'media': [{u'subtype': u'photo', u'caption': u'', u'media-metadata': [{u'url': u'http://graphics8.nytimes.com/images/2014/02/16/sunday-review/16COVER/16COVER-thumbStandard.jpg', u'width': 75, u'format': u'Standard Thumbnail', u'height': 75}, {u'url': u'http://graphics8.nytimes.com/images/2014/02/16/sunday-review/16COVER/16COVER-superJumbo.jpg', u'width': 2048, u'format': u'superJumbo', u'height': 1552}, {u'url': u'http://graphics8.nytimes.com/images/2014/02/16/sunday-review/16COVER/16COVER-sfSpan.jpg', u'width': 395, u'format': u'Large', u'height': 263}, {u'url': u'http://graphics8.nytimes.com/images/2014/02/16/sunday-review/16COVER/16COVER-thumbLarge.jpg', u'width': 150, u'format': u'thumbLarge', u'height': 150}, {u'url': u'http://graphics8.nytimes.com/images/2014/02/16/sunday-review/16COVER/16COVER-articleInline.jpg', u'width': 190, u'format': u'Normal', u'height': 144}, {u'url': u'http://graphics8.nytimes.com/images/2014/02/16/sunday-review/16COVER/16COVER-square640.jpg', u'width': 640, u'format': u'square640', u'height': 640}, {u'url': u'http://graphics8.nytimes.com/images/2014/02/16/sunday-review/16COVER/16COVER-square320.jpg', u'width': 320, u'format': u'square320', u'height': 320}, {u'url': u'http://graphics8.nytimes.com/images/2014/02/16/sunday-review/16COVER/16COVER-mediumThreeByTwo210.jpg', u'width': 210, u'format': u'mediumThreeByTwo210', u'height': 140}], u'copyright': u'Pieter Van Eenoge', u'type': u'image'}, {u'subtype': u'photo', u'caption': u'', u'media-metadata': [{u'url': u'http://graphics8.nytimes.com/images/2014/02/16/sunday-review/16MARRIAGEJP/16MARRIAGEJP-thumbStandard.jpg', u'width': 75, u'format': u'Standard Thumbnail', u'height': 75}, {u'url': u'http://graphics8.nytimes.com/images/2014/02/16/sunday-review/16MARRIAGEJP/16MARRIAGEJP-superJumbo.jpg', u'width': 2048, u'format': u'superJumbo', u'height': 1815}, {u'url': u'http://graphics8.nytimes.com/images/2014/02/16/sunday-review/16MARRIAGEJP/16MARRIAGEJP-sfSpan.jpg', u'width': 395, u'format': u'Large', u'height': 263}, {u'url': u'http://graphics8.nytimes.com/images/2014/02/16/sunday-review/16MARRIAGEJP/16MARRIAGEJP-thumbLarge.jpg', u'width': 150, u'format': u'thumbLarge', u'height': 150}, {u'url': u'http://graphics8.nytimes.com/images/2014/02/16/sunday-review/16MARRIAGEJP/16MARRIAGEJP-articleInline.jpg', u'width': 190, u'format': u'Normal', u'height': 168}, {u'url': u'http://graphics8.nytimes.com/images/2014/02/16/sunday-review/16MARRIAGEJP/16MARRIAGEJP-square640.jpg', u'width': 640, u'format': u'square640', u'height': 640}, {u'url': u'http://graphics8.nytimes.com/images/2014/02/16/sunday-review/16MARRIAGEJP/16MARRIAGEJP-square320.jpg', u'width': 320, u'format': u'square320', u'height': 320}, {u'url': u'http://graphics8.nytimes.com/images/2014/02/16/sunday-review/16MARRIAGEJP/16MARRIAGEJP-mediumThreeByTwo210.jpg', u'width': 210, u'format': u'mediumThreeByTwo210', u'height': 140}], u'copyright': u'Pieter Van Eenoge', u'type': u'image'}], u'section': u'Opinion', u'views': 1, u'column': u'Opinion', u'published_date': u'2014-02-16', u'abstract': u'Couples can be happier now than ever before. But it\u2019s rare.', u'des_facet': [u'MARRIAGES', u'DIVORCE, SEPARATIONS AND ANNULMENTS', u'SOCIAL CONDITIONS AND TRENDS', u'SOCIOLOGY'], u'geo_facet': u'', u'adx_keywords': u'Marriages;Divorce, Separations and Annulments;Social Conditions and Trends;Sociology', u'source': u'The New York Times', u'org_facet': u'', u'per_facet': u'', u'type': u'Article', u'id': u'100000002711649'}, {u'asset_id': 100000002713490.0, u'byline': u'By MAUREEN DOWD', u'title': u'Marry First, Then Cheat', u'url': u'http://www.nytimes.com/2014/02/16/opinion/sunday/dowd-marry-first-then-cheat.html', u'media': [{u'subtype': u'photo', u'caption': u'At the Louvre on Friday, love was in the air, in co ...
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-83-05d784dd3b01> in <module>()
#     105
#     106
# --> 107 test()
#
# <ipython-input-83-05d784dd3b01> in test()
#      99 def test():
#     100     titles, urls = article_overview("viewed", 1)
# --> 101     assert len(titles) == 20
#     102     assert len(urls) == 30
#     103     assert titles[2] == {'Opinion': 'Professors, We Need You!'}
#
# AssertionError:
