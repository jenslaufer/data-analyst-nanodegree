# %% [markdown]
# # Titanic Data Evaluation

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.stats.api as sms
from scipy import stats

filename = 'titanic-data.csv'

df = pd.read_csv(filename)

# %%
def isChild(x):
    if x > 18:
        return True
    else:
        return False
df["IsChild"] = pd.Series(df["Age"].apply(isChild), index=df.index)

# %% [markdown]
# ## Plots ##

# %%
# %matplotlib inline

sns.set(style="darkgrid")
sns.barplot(data=df,x="Sex",y="Survived", palette="GnBu_d")
sns.plt.show()
sns.barplot(data=df,x="IsChild",y="Survived", palette="GnBu_d")
sns.plt.show()

# %%
sns.barplot(data=df, x="Sex", y="Survived", hue="IsChild", palette="GnBu_d")

# %%
sns.jointplot("Age", "Survived", data=df,
                   kind="kde", space=0, color="b")

# %%
sns.boxplot(df.Age)

# %%
sns.violinplot(df.Age,df.Sex)

# %%
df.hist(figsize=(2,2))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000001357E5F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000128050F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000128BDB70>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000012897748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B86CC50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000121D8048>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000012C4EC18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000013AD37F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000013B77DA0>]], dtype=object)

# %%
sns.lmplot(x="Pclass", y="Survived", data=df, logistic=True, y_jitter=.05, fit_reg=True)
